# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			line = normalize('NFD', line).encode('ascii', 'ignore')
			line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
			line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'tur.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-turkish.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-turkish.pkl
# [hi] => [selam]
# [hi] => [merhaba]
# [run] => [kac]
# [run] => [kos]
# [run] => [kac]
# [run] => [kos]
# [who] => [kim]
# [wow] => [vay canna]
# [fire] => [ates]
# [fire] => [yangn]
# [fire] => [ates et]
# [help] => [yardm et]
# [help] => [imdat]
# [jump] => [atla]
# [jump] => [defol]
# [jump] => [git]
# [jump] => [atla]
# [stop] => [dur]
# [stop] => [brak]
# [wait] => [bekle]
# [do it] => [onu yap]
# [go on] => [devam et]
# [go on] => [devam edin]
# [hello] => [selam]
# [hurry] => [acele et]
# [i ran] => [kostum]
# [i see] => [anlyorum]
# [i see] => [goruyorum]
# [i won] => [kazandm]
# [oh no] => [oh hayr]
# [relax] => [rahatla]
# [shoot] => [ates]
# [shoot] => [ates et]
# [shoot] => [vur]
# [smile] => [gulumse]
# [attack] => [saldr]
# [attack] => [hucum]
# [cheers] => [yarasn]
# [cheers] => [serefe]
# [eat it] => [bunu ye]
# [eat up] => [silip supur]
# [freeze] => [kmldama]
# [freeze] => [oldugun yerde kal]
# [go now] => [simdi git]
# [go now] => [haydi git]
# [go now] => [git artk]
# [go now] => [gidin artk]
# [got it] => [anladm]
# [got it] => [anladn m]
# [he ran] => [o kostu]
# [hop in] => [atla]
# [i fell] => [ben dustum]
# [i knit] => [orgu oruyorum]
# [i know] => [biliyorum]
# [i left] => [ben ayrldm]
# [i lost] => [kayboldum]
# [i paid] => [odedim]
# [i quit] => [ben istifa ettim]
# [i swim] => [yuzerim]
# [i work] => [calsyorum]
# [im] => [ben yasndaym]
# [im ok] => [ben iyiyim]
# [im up] => [ben uyangm]
# [no way] => [mumkun degil]
# [no way] => [asla]
# [really] => [gercekten mi]
# [really] => [valla m]
# [really] => [esas m]
# [really] => [harbi mi]
# [really] => [harbiden mi]
# [really] => [sahiden mi]
# [really] => [hakikaten mi]
# [really] => [harbici misin]
# [really] => [cidden mi]
# [thanks] => [tesekkurler]
# [try it] => [bunu dene]
# [we ate] => [biz yemek yedik]
# [we try] => [biz deneriz]
# [we try] => [biz cabalarz]
# [we won] => [biz kazandk]
# [why me] => [neden ben]
# [why me] => [nicin ben]
# [why me] => [niye ben]
# [ask tom] => [toma sor]
# [ask him] => [ona sor]
# [be calm] => [sakin olun]
# [be cool] => [sakin ol]
# [be cool] => [rahat ol]
# [be fair] => [adil ol]
# [be kind] => [nazik ol]
# [be nice] => [kibar ol]
# [be nice] => [nazik ol]
# [beat it] => [defol]
# [burn it] => [yak onu]
# [bury it] => [onu gom]
# [call me] => [ara beni]
# [come in] => [gelin]
# [drop it] => [kapat su konuyu artk]
# [fold it] => [onu katla]
# [get tom] => [tomu aln]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-turkish.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[1000:]
# save
save_clean_data(dataset, 'english-turkish-both.pkl')
save_clean_data(train, 'english-turkish-train.pkl')
save_clean_data(test, 'english-turkish-test.pkl')
# Out:
# Saved: english-turkish-both.pkl
# Saved: english-turkish-train.pkl
# Saved: english-turkish-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-turkish-both.pkl')
train = load_clean_sentences('english-turkish-train.pkl')
test = load_clean_sentences('english-turkish-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('Turkish Vocabulary Size: %d' % ger_vocab_size)
print('Turkish Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2445
# English Max Length: 5
# Turkish Vocabulary Size: 5548
# Turkish Max Length: 6
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 6, 256)            1420288
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 5, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 5, 2445)           628365
# =================================================================
# Total params: 3,099,277
# Trainable params: 3,099,277
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 141/141 - 29s - loss: 4.3331 - val_loss: 3.3571
#
# Epoch 00001: val_loss improved from inf to 3.35710, saving model to model.h5
# Epoch 2/100
# 141/141 - 22s - loss: 3.2524 - val_loss: 3.1263
#
# Epoch 00002: val_loss improved from 3.35710 to 3.12626, saving model to model.h5
# Epoch 3/100
# 141/141 - 22s - loss: 3.0740 - val_loss: 2.9759
#
# Epoch 00003: val_loss improved from 3.12626 to 2.97593, saving model to model.h5
# Epoch 4/100
# 141/141 - 22s - loss: 2.9295 - val_loss: 2.8369
#
# Epoch 00004: val_loss improved from 2.97593 to 2.83691, saving model to model.h5
# Epoch 5/100
# 141/141 - 22s - loss: 2.7832 - val_loss: 2.6992
#
# Epoch 00005: val_loss improved from 2.83691 to 2.69922, saving model to model.h5
# Epoch 6/100
# 141/141 - 22s - loss: 2.6301 - val_loss: 2.5438
#
# Epoch 00006: val_loss improved from 2.69922 to 2.54385, saving model to model.h5
# Epoch 7/100
# 141/141 - 22s - loss: 2.4822 - val_loss: 2.4062
#
# Epoch 00007: val_loss improved from 2.54385 to 2.40620, saving model to model.h5
# Epoch 8/100
# 141/141 - 22s - loss: 2.3449 - val_loss: 2.2756
#
# Epoch 00008: val_loss improved from 2.40620 to 2.27562, saving model to model.h5
# Epoch 9/100
# 141/141 - 22s - loss: 2.2078 - val_loss: 2.1463
#
# Epoch 00009: val_loss improved from 2.27562 to 2.14628, saving model to model.h5
# Epoch 10/100
# 141/141 - 22s - loss: 2.0751 - val_loss: 2.0265
#
# Epoch 00010: val_loss improved from 2.14628 to 2.02650, saving model to model.h5
# Epoch 11/100
# 141/141 - 22s - loss: 1.9461 - val_loss: 1.9161
#
# Epoch 00011: val_loss improved from 2.02650 to 1.91605, saving model to model.h5
# Epoch 12/100
# 141/141 - 22s - loss: 1.8270 - val_loss: 1.8030
#
# Epoch 00012: val_loss improved from 1.91605 to 1.80304, saving model to model.h5
# Epoch 13/100
# 141/141 - 22s - loss: 1.7132 - val_loss: 1.6947
#
# Epoch 00013: val_loss improved from 1.80304 to 1.69465, saving model to model.h5
# Epoch 14/100
# 141/141 - 22s - loss: 1.6053 - val_loss: 1.6022
#
# Epoch 00014: val_loss improved from 1.69465 to 1.60217, saving model to model.h5
# Epoch 15/100
# 141/141 - 21s - loss: 1.5001 - val_loss: 1.5078
#
# Epoch 00015: val_loss improved from 1.60217 to 1.50781, saving model to model.h5
# Epoch 16/100
# 141/141 - 22s - loss: 1.4028 - val_loss: 1.4234
#
# Epoch 00016: val_loss improved from 1.50781 to 1.42344, saving model to model.h5
# Epoch 17/100
# 141/141 - 22s - loss: 1.3138 - val_loss: 1.3418
#
# Epoch 00017: val_loss improved from 1.42344 to 1.34181, saving model to model.h5
# Epoch 18/100
# 141/141 - 22s - loss: 1.2260 - val_loss: 1.2698
#
# Epoch 00018: val_loss improved from 1.34181 to 1.26983, saving model to model.h5
# Epoch 19/100
# 141/141 - 22s - loss: 1.1422 - val_loss: 1.1966
#
# Epoch 00019: val_loss improved from 1.26983 to 1.19662, saving model to model.h5
# Epoch 20/100
# 141/141 - 22s - loss: 1.0613 - val_loss: 1.1202
#
# Epoch 00020: val_loss improved from 1.19662 to 1.12019, saving model to model.h5
# Epoch 21/100
# 141/141 - 22s - loss: 0.9833 - val_loss: 1.0589
#
# Epoch 00021: val_loss improved from 1.12019 to 1.05893, saving model to model.h5
# Epoch 22/100
# 141/141 - 22s - loss: 0.9091 - val_loss: 0.9942
#
# Epoch 00022: val_loss improved from 1.05893 to 0.99418, saving model to model.h5
# Epoch 23/100
# 141/141 - 22s - loss: 0.8357 - val_loss: 0.9330
#
# Epoch 00023: val_loss improved from 0.99418 to 0.93305, saving model to model.h5
# Epoch 24/100
# 141/141 - 22s - loss: 0.7678 - val_loss: 0.8708
#
# Epoch 00024: val_loss improved from 0.93305 to 0.87084, saving model to model.h5
# Epoch 25/100
# 141/141 - 22s - loss: 0.7026 - val_loss: 0.8181
#
# Epoch 00025: val_loss improved from 0.87084 to 0.81806, saving model to model.h5
# Epoch 26/100
# 141/141 - 22s - loss: 0.6416 - val_loss: 0.7700
#
# Epoch 00026: val_loss improved from 0.81806 to 0.77002, saving model to model.h5
# Epoch 27/100
# 141/141 - 22s - loss: 0.5844 - val_loss: 0.7238
#
# Epoch 00027: val_loss improved from 0.77002 to 0.72376, saving model to model.h5
# Epoch 28/100
# 141/141 - 23s - loss: 0.5328 - val_loss: 0.6814
#
# Epoch 00028: val_loss improved from 0.72376 to 0.68141, saving model to model.h5
# Epoch 29/100
# 141/141 - 22s - loss: 0.4824 - val_loss: 0.6433
#
# Epoch 00029: val_loss improved from 0.68141 to 0.64332, saving model to model.h5
# Epoch 30/100
# 141/141 - 23s - loss: 0.4365 - val_loss: 0.6103
#
# Epoch 00030: val_loss improved from 0.64332 to 0.61027, saving model to model.h5
# Epoch 31/100
# 141/141 - 23s - loss: 0.3983 - val_loss: 0.5802
#
# Epoch 00031: val_loss improved from 0.61027 to 0.58023, saving model to model.h5
# Epoch 32/100
# 141/141 - 22s - loss: 0.3623 - val_loss: 0.5569
#
# Epoch 00032: val_loss improved from 0.58023 to 0.55689, saving model to model.h5
# Epoch 33/100
# 141/141 - 22s - loss: 0.3316 - val_loss: 0.5317
#
# Epoch 00033: val_loss improved from 0.55689 to 0.53170, saving model to model.h5
# Epoch 34/100
# 141/141 - 22s - loss: 0.3032 - val_loss: 0.5116
#
# Epoch 00034: val_loss improved from 0.53170 to 0.51158, saving model to model.h5
# Epoch 35/100
# 141/141 - 22s - loss: 0.2772 - val_loss: 0.4920
#
# Epoch 00035: val_loss improved from 0.51158 to 0.49200, saving model to model.h5
# Epoch 36/100
# 141/141 - 22s - loss: 0.2557 - val_loss: 0.4790
#
# Epoch 00036: val_loss improved from 0.49200 to 0.47895, saving model to model.h5
# Epoch 37/100
# 141/141 - 22s - loss: 0.2370 - val_loss: 0.4670
#
# Epoch 00037: val_loss improved from 0.47895 to 0.46702, saving model to model.h5
# Epoch 38/100
# 141/141 - 22s - loss: 0.2203 - val_loss: 0.4555
#
# Epoch 00038: val_loss improved from 0.46702 to 0.45551, saving model to model.h5
# Epoch 39/100
# 141/141 - 22s - loss: 0.2071 - val_loss: 0.4461
#
# Epoch 00039: val_loss improved from 0.45551 to 0.44614, saving model to model.h5
# Epoch 40/100
# 141/141 - 22s - loss: 0.1935 - val_loss: 0.4366
#
# Epoch 00040: val_loss improved from 0.44614 to 0.43665, saving model to model.h5
# Epoch 41/100
# 141/141 - 22s - loss: 0.1816 - val_loss: 0.4305
#
# Epoch 00041: val_loss improved from 0.43665 to 0.43053, saving model to model.h5
# Epoch 42/100
# 141/141 - 22s - loss: 0.1713 - val_loss: 0.4225
#
# Epoch 00042: val_loss improved from 0.43053 to 0.42251, saving model to model.h5
# Epoch 43/100
# 141/141 - 22s - loss: 0.1633 - val_loss: 0.4186
#
# Epoch 00043: val_loss improved from 0.42251 to 0.41860, saving model to model.h5
# Epoch 44/100
# 141/141 - 22s - loss: 0.1556 - val_loss: 0.4137
#
# Epoch 00044: val_loss improved from 0.41860 to 0.41374, saving model to model.h5
# Epoch 45/100
# 141/141 - 22s - loss: 0.1512 - val_loss: 0.4096
#
# Epoch 00045: val_loss improved from 0.41374 to 0.40963, saving model to model.h5
# Epoch 46/100
# 141/141 - 22s - loss: 0.1444 - val_loss: 0.4076
#
# Epoch 00046: val_loss improved from 0.40963 to 0.40760, saving model to model.h5
# Epoch 47/100
# 141/141 - 22s - loss: 0.1386 - val_loss: 0.4047
#
# Epoch 00047: val_loss improved from 0.40760 to 0.40466, saving model to model.h5
# Epoch 48/100
# 141/141 - 22s - loss: 0.1338 - val_loss: 0.4057
#
# Epoch 00048: val_loss did not improve from 0.40466
# Epoch 49/100
# 141/141 - 22s - loss: 0.1310 - val_loss: 0.4014
#
# Epoch 00049: val_loss improved from 0.40466 to 0.40140, saving model to model.h5
# Epoch 50/100
# 141/141 - 22s - loss: 0.1258 - val_loss: 0.3984
#
# Epoch 00050: val_loss improved from 0.40140 to 0.39840, saving model to model.h5
# Epoch 51/100
# 141/141 - 22s - loss: 0.1223 - val_loss: 0.3969
#
# Epoch 00051: val_loss improved from 0.39840 to 0.39691, saving model to model.h5
# Epoch 52/100
# 141/141 - 22s - loss: 0.1203 - val_loss: 0.3985
#
# Epoch 00052: val_loss did not improve from 0.39691
# Epoch 53/100
# 141/141 - 22s - loss: 0.1175 - val_loss: 0.3952
#
# Epoch 00053: val_loss improved from 0.39691 to 0.39515, saving model to model.h5
# Epoch 54/100
# 141/141 - 22s - loss: 0.1157 - val_loss: 0.3940
#
# Epoch 00054: val_loss improved from 0.39515 to 0.39397, saving model to model.h5
# Epoch 55/100
# 141/141 - 22s - loss: 0.1124 - val_loss: 0.3930
#
# Epoch 00055: val_loss improved from 0.39397 to 0.39295, saving model to model.h5
# Epoch 56/100
# 141/141 - 22s - loss: 0.1104 - val_loss: 0.3951
#
# Epoch 00056: val_loss did not improve from 0.39295
# Epoch 57/100
# 141/141 - 22s - loss: 0.1093 - val_loss: 0.3952
#
# Epoch 00057: val_loss did not improve from 0.39295
# Epoch 58/100
# 141/141 - 22s - loss: 0.1074 - val_loss: 0.3930
#
# Epoch 00058: val_loss did not improve from 0.39295
# Epoch 59/100
# 141/141 - 21s - loss: 0.1066 - val_loss: 0.3915
#
# Epoch 00059: val_loss improved from 0.39295 to 0.39152, saving model to model.h5
# Epoch 60/100
# 141/141 - 22s - loss: 0.1052 - val_loss: 0.3915
#
# Epoch 00060: val_loss improved from 0.39152 to 0.39147, saving model to model.h5
# Epoch 61/100
# 141/141 - 22s - loss: 0.1038 - val_loss: 0.3942
#
# Epoch 00061: val_loss did not improve from 0.39147
# Epoch 62/100
# 141/141 - 22s - loss: 0.1041 - val_loss: 0.3937
#
# Epoch 00062: val_loss did not improve from 0.39147
# Epoch 63/100
# 141/141 - 22s - loss: 0.1026 - val_loss: 0.3945
#
# Epoch 00063: val_loss did not improve from 0.39147
# Epoch 64/100
# 141/141 - 22s - loss: 0.1010 - val_loss: 0.3931
#
# Epoch 00064: val_loss did not improve from 0.39147
# Epoch 65/100
# 141/141 - 22s - loss: 0.1012 - val_loss: 0.3919
#
# Epoch 00065: val_loss did not improve from 0.39147
# Epoch 66/100
# 141/141 - 21s - loss: 0.1000 - val_loss: 0.3972
#
# Epoch 00066: val_loss did not improve from 0.39147
# Epoch 67/100
# 141/141 - 21s - loss: 0.0984 - val_loss: 0.3932
#
# Epoch 00067: val_loss did not improve from 0.39147
# Epoch 68/100
# 141/141 - 21s - loss: 0.0978 - val_loss: 0.3961
#
# Epoch 00068: val_loss did not improve from 0.39147
# Epoch 69/100
# 141/141 - 21s - loss: 0.0965 - val_loss: 0.3926
#
# Epoch 00069: val_loss did not improve from 0.39147
# Epoch 70/100
# 141/141 - 22s - loss: 0.0960 - val_loss: 0.3920
#
# Epoch 00070: val_loss did not improve from 0.39147
# Epoch 71/100
# 141/141 - 22s - loss: 0.0937 - val_loss: 0.3953
#
# Epoch 00071: val_loss did not improve from 0.39147
# Epoch 72/100
# 141/141 - 22s - loss: 0.0931 - val_loss: 0.3958
#
# Epoch 00072: val_loss did not improve from 0.39147
# Epoch 73/100
# 141/141 - 22s - loss: 0.0922 - val_loss: 0.3934
#
# Epoch 00073: val_loss did not improve from 0.39147
# Epoch 74/100
# 141/141 - 22s - loss: 0.0916 - val_loss: 0.3944
#
# Epoch 00074: val_loss did not improve from 0.39147
# Epoch 75/100
# 141/141 - 22s - loss: 0.0923 - val_loss: 0.3941
#
# Epoch 00075: val_loss did not improve from 0.39147
# Epoch 76/100
# 141/141 - 23s - loss: 0.0938 - val_loss: 0.3950
#
# Epoch 00076: val_loss did not improve from 0.39147
# Epoch 77/100
# 141/141 - 23s - loss: 0.0942 - val_loss: 0.3995
#
# Epoch 00077: val_loss did not improve from 0.39147
# Epoch 78/100
# 141/141 - 22s - loss: 0.0933 - val_loss: 0.3969
#
# Epoch 00078: val_loss did not improve from 0.39147
# Epoch 79/100
# 141/141 - 22s - loss: 0.0919 - val_loss: 0.3976
#
# Epoch 00079: val_loss did not improve from 0.39147
# Epoch 80/100
# 141/141 - 22s - loss: 0.0914 - val_loss: 0.3966
#
# Epoch 00080: val_loss did not improve from 0.39147
# Epoch 81/100
# 141/141 - 22s - loss: 0.0901 - val_loss: 0.3953
#
# Epoch 00081: val_loss did not improve from 0.39147
# Epoch 82/100
# 141/141 - 22s - loss: 0.0889 - val_loss: 0.3940
#
# Epoch 00082: val_loss did not improve from 0.39147
# Epoch 83/100
# 141/141 - 22s - loss: 0.0882 - val_loss: 0.3951
#
# Epoch 00083: val_loss did not improve from 0.39147
# Epoch 84/100
# 141/141 - 22s - loss: 0.0894 - val_loss: 0.3966
#
# Epoch 00084: val_loss did not improve from 0.39147
# Epoch 85/100
# 141/141 - 22s - loss: 0.0931 - val_loss: 0.3984
#
# Epoch 00085: val_loss did not improve from 0.39147
# Epoch 86/100
# 141/141 - 22s - loss: 0.0920 - val_loss: 0.4022
#
# Epoch 00086: val_loss did not improve from 0.39147
# Epoch 87/100
# 141/141 - 22s - loss: 0.0902 - val_loss: 0.3977
#
# Epoch 00087: val_loss did not improve from 0.39147
# Epoch 88/100
# 141/141 - 22s - loss: 0.0896 - val_loss: 0.3994
#
# Epoch 00088: val_loss did not improve from 0.39147
# Epoch 89/100
# 141/141 - 22s - loss: 0.0875 - val_loss: 0.3993
#
# Epoch 00089: val_loss did not improve from 0.39147
# Epoch 90/100
# 141/141 - 22s - loss: 0.0859 - val_loss: 0.3982
#
# Epoch 00090: val_loss did not improve from 0.39147
# Epoch 91/100
# 141/141 - 22s - loss: 0.0855 - val_loss: 0.3986
#
# Epoch 00091: val_loss did not improve from 0.39147
# Epoch 92/100
# 141/141 - 22s - loss: 0.0848 - val_loss: 0.3979
#
# Epoch 00092: val_loss did not improve from 0.39147
# Epoch 93/100
# 141/141 - 22s - loss: 0.0840 - val_loss: 0.4002
#
# Epoch 00093: val_loss did not improve from 0.39147
# Epoch 94/100
# 141/141 - 22s - loss: 0.0834 - val_loss: 0.3994
#
# Epoch 00094: val_loss did not improve from 0.39147
# Epoch 95/100
# 141/141 - 22s - loss: 0.0834 - val_loss: 0.3995
#
# Epoch 00095: val_loss did not improve from 0.39147
# Epoch 96/100
# 141/141 - 22s - loss: 0.0841 - val_loss: 0.3981
#
# Epoch 00096: val_loss did not improve from 0.39147
# Epoch 97/100
# 141/141 - 22s - loss: 0.0836 - val_loss: 0.4007
#
# Epoch 00097: val_loss did not improve from 0.39147
# Epoch 98/100
# 141/141 - 22s - loss: 0.0842 - val_loss: 0.4010
#
# Epoch 00098: val_loss did not improve from 0.39147
# Epoch 99/100
# 141/141 - 23s - loss: 0.0836 - val_loss: 0.4002
#
# Epoch 00099: val_loss did not improve from 0.39147
# Epoch 100/100
# 141/141 - 22s - loss: 0.0833 - val_loss: 0.4045
#
# Epoch 00100: val_loss did not improve from 0.39147

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,test = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-turkish-both.pkl')
train = load_clean_sentences('english-turkish-train.pkl')
test = load_clean_sentences('english-turkish-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[tom neredeydi], target=[where was tom], predicted=[where was tom]
# src=[gonullu oldum], target=[i volunteered], predicted=[i volunteered]
# src=[ben denedim], target=[ive tried], predicted=[ive tried]
# src=[tomu gorecegim], target=[ill see tom], predicted=[ill see tom]
# src=[hayat zordur], target=[life is hard], predicted=[life is tough]
# src=[sen kotusun], target=[youre bad], predicted=[youre bad]
# src=[besbelli ki], target=[of course], predicted=[of course]
# src=[sgnacak yer ara], target=[run for cover], predicted=[run for cover]
# src=[iyi calsyor], target=[it works well], predicted=[it works well]
# src=[ben kactm], target=[i got away], predicted=[i escaped away]
# BLEU-1: 0.944111
# BLEU-2: 0.923439
# BLEU-3: 0.840099
# BLEU-4: 0.475503
# test
# src=[sersem hissediyorum], target=[i feel giddy], predicted=[i feel giddy]
# src=[misafirimiz olun], target=[be our guest], predicted=[be our guest]
# src=[bu zor], target=[its hard], predicted=[its is]
# src=[onlar tomu aldlar], target=[they got tom], predicted=[they got tom]
# src=[kim telefon etti], target=[who phoned], predicted=[who phoned]
# src=[ben hala sark soyluyorum], target=[i still sing], predicted=[i still sing]
# src=[biz haklyz], target=[were right], predicted=[were right]
# src=[o hayr anlamna geliyordu], target=[that meant no], predicted=[that meant no]
# src=[tom cay sever], target=[tom likes tea], predicted=[tom likes tea]
# src=[tom aglamad m], target=[didnt tom cry], predicted=[didnt tom cry]
# BLEU-1: 0.887038
# BLEU-2: 0.856656
# BLEU-3: 0.777701
# BLEU-4: 0.434650
